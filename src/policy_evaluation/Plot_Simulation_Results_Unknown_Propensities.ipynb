# %%
import sys
# sys.path.insert(0, '../ATE_Simulations/Results')
sys.path.insert(0, '../../src')
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
import os
from visualization_utils import perc, SetPlotRC, ApplyFont

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Number of Observations Experiments

# %%
full_results1 = pd.read_csv(r"Results_UnknownProps/OPE_n_observations_result_100_observations_Unknown_Propensities.csv")
full_results2 = pd.read_csv(r"Results_UnknownProps/OPE_n_observations_result_1000_observations_Unknown_Propensities.csv")
full_results3 = pd.read_csv(r"Results_UnknownProps/OPE_n_observations_result_2000_observations_Unknown_Propensities.csv")
full_results4 = pd.read_csv(r"Results_UnknownProps/OPE_n_observations_result_5000_observations_Unknown_Propensities.csv")
# full_results5 = pd.read_csv(r"Results/OPE_n_observations_result_10000_observations.csv")
full_results = pd.concat([full_results1, full_results2, full_results3, full_results4])
SetPlotRC()
# # Plotting results
# sns.set(style="whitegrid")
# plt.figure(figsize=(8, 5))
# sns.boxplot(
#     data=full_results, x="Observation Size", y="MSE", hue="Estimator"
#     # , marker="o"
# )
# plt.yscale("log")
# plt.title("Number of Observations vs MSE")
# plt.tight_layout()
# ApplyFont(plt.gca(), xlabel_text_size = 15.0, ylabel_text_size = 15.0, title_text_size = 15.0, ticks_text_size = 15,)
# plt.show()

# Plotting results
sns.set(style="whitegrid")
plt.figure(figsize=(8, 5))
sns.pointplot(
    data=full_results, x="Observation Size", y="MSE", hue="Estimator"
    # , marker="o"
)
plt.yscale("log")
plt.title("Number of Observations vs MSE")
plt.tight_layout()
ApplyFont(plt.gca(), xlabel_text_size = 15.0, ylabel_text_size = 15.0, title_text_size = 15.0, ticks_text_size = 15,)
plt.show()

# %% [markdown]
# # Number of Context Experiments

# %%
full_results1 = pd.read_csv(r"Results/OPE_n_context_result_5_to_15.csv")
full_results2 = pd.read_csv(r"Results/OPE_n_context_result_20_to_30.csv")
full_results = pd.concat([full_results1, full_results2])
SetPlotRC()

# # Plotting results
# sns.set(style="whitegrid")
# plt.figure(figsize=(8, 5))
# sns.boxplot(
#     data=full_results, x="context_dim", y="MSE", hue="Estimator"
#     # , marker="o"
# )
# plt.yscale("log")
# plt.title("Number of Context vs MSE")
# plt.tight_layout()
# ApplyFont(plt.gca(), xlabel_text_size = 15.0, ylabel_text_size = 15.0, title_text_size = 15.0, ticks_text_size = 15,)
# plt.show()

# Plotting results
sns.set(style="whitegrid")
plt.figure(figsize=(8, 5))
sns.pointplot(
    data=full_results, x="context_dim", y="MSE", hue="Estimator"
    # , marker="o"
)
plt.yscale("log")
plt.title("Number of Context vs MSE")
plt.tight_layout()
ApplyFont(plt.gca(), xlabel_text_size = 15.0, ylabel_text_size = 15.0, title_text_size = 15.0, ticks_text_size = 15,)
plt.show()

# %% [markdown]
# # Domain Shift Experiments

# %%
full_results1 = pd.read_csv(r"Results_UnknownProps/OPE_domain_shift_result_07_upto_09_Unknown_Propensities.csv")
full_results2 = pd.read_csv(r"Results_UnknownProps/OPE_domain_shift_result_minus03_upto_05_Unknown_Propensities.csv")
full_results3 = pd.read_csv(r"Results_UnknownProps/OPE_domain_shift_result_minus09_upto_minus05_Unknown_Propensities.csv")
full_results = pd.concat([full_results1, full_results2, full_results3])
SetPlotRC()

# # Plotting results
# sns.set(style="whitegrid")
# plt.figure(figsize=(8, 5))
# sns.boxplot(
#     data=full_results, x="alpha_multiplier", y="MSE", hue="Estimator"
#     # , marker="o"
# )
# plt.yscale("log")
# plt.title("MSE under domain shift")
# plt.tight_layout()
# ApplyFont(plt.gca(), xlabel_text_size = 15.0, ylabel_text_size = 15.0, title_text_size = 15.0, ticks_text_size = 15,)
# plt.show()

# Plotting results
sns.set(style="whitegrid")
plt.figure(figsize=(8, 5))
sns.pointplot(
    data=full_results, x="alpha_multiplier", y="MSE", hue="Estimator"
    # , marker="o"
)
plt.yscale("log")
plt.title("MSE under domain shift")
plt.tight_layout()
ApplyFont(plt.gca(), xlabel_text_size = 15.0, ylabel_text_size = 15.0, title_text_size = 15.0, ticks_text_size = 15,)
plt.show()

# %% [markdown]
# # Number of Recommendations Experiments

# %%
full_results1 = pd.read_csv(r"Results_UnknownProps/OPE_n_recommendations_result_n_reco_2_to_4_Unknown_Propensities.csv")
full_results2 = pd.read_csv(r"Results_UnknownProps/OPE_n_recommendations_result_n_reco_5_to_7_Unknown_Propensities.csv")
full_results = pd.concat([full_results1, full_results2])
SetPlotRC()

# # Plotting results
# sns.set(style="whitegrid")
# plt.figure(figsize=(8, 5))
# sns.boxplot(
#     data=full_results, x="n_reco", y="MSE", hue="Estimator"
#     # , marker="o"
# )
# plt.yscale("log")
# plt.title("Number of Recommendations vs MSE")
# plt.tight_layout()
# ApplyFont(plt.gca(), xlabel_text_size = 15.0, ylabel_text_size = 15.0, title_text_size = 15.0, ticks_text_size = 15,)
# plt.show()

# Plotting results
sns.set(style="whitegrid")
plt.figure(figsize=(8, 5))
sns.pointplot(
    data=full_results, x="n_reco", y="MSE", hue="Estimator"
    # , marker="o"
)
plt.yscale("log")
plt.title("Number of Recommendations vs MSE")
plt.tight_layout()
ApplyFont(plt.gca(), xlabel_text_size = 15.0, ylabel_text_size = 15.0, title_text_size = 15.0, ticks_text_size = 15,)
plt.show()

# %% [markdown]
# # Number of Users Experiment

# %%
full_results1 = pd.read_csv(r"Results_UnknownProps/OPE_n_users_result_50_to_100_Unknown_Propensities.csv")
full_results2 = pd.read_csv(r"Results_UnknownProps/OPE_n_users_result_150_to_200_Unknown_Propensities.csv")
# full_results3 = pd.read_csv(r"Results_UnknownProps/OPE_n_users_result_250_to_300_Unknown_Propensities.csv")
full_results = pd.concat([full_results1, full_results2])
SetPlotRC()

# # Plotting results
# sns.set(style="whitegrid")
# plt.figure(figsize=(8, 5))
# sns.boxplot(
#     data=full_results, x="n_reco", y="MSE", hue="Estimator"
#     # , marker="o"
# )
# plt.yscale("log")
# plt.title("Number of Recommendations vs MSE")
# plt.tight_layout()
# ApplyFont(plt.gca(), xlabel_text_size = 15.0, ylabel_text_size = 15.0, title_text_size = 15.0, ticks_text_size = 15,)
# plt.show()

# Plotting results
sns.set(style="whitegrid")
plt.figure(figsize=(8, 5))
sns.pointplot(
    data=full_results, x="n_users", y="MSE", hue="Estimator"
    # , marker="o"
)
plt.yscale("log")
plt.title("Number of Users vs MSE")
plt.tight_layout()
ApplyFont(plt.gca(), xlabel_text_size = 15.0, ylabel_text_size = 15.0, title_text_size = 15.0, ticks_text_size = 15,)
plt.show()
