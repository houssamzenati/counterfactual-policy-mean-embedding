# %%
import sys
# sys.path.insert(0, '../ATE_Simulations/Results')
sys.path.insert(0, '../../src')
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
import os
from visualization_utils import perc, SetPlotRC, ApplyFont

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Number of Items Experiments

# %%
full_results = pd.read_csv(r"Results/OPE_n_observations_result_10iter.csv")
SetPlotRC()
# Plotting results
sns.set(style="whitegrid")
plt.figure(figsize=(8, 5))
sns.boxplot(
    data=full_results, x="Observation Size", y="MSE", hue="Estimator"
    # , marker="o"
)
plt.yscale("log")
plt.title("Number of Observations vs MSE")
plt.tight_layout()
ApplyFont(plt.gca(), xlabel_text_size = 15.0, ylabel_text_size = 15.0, title_text_size = 15.0, ticks_text_size = 15,)
plt.show()

# %%
full_results = pd.read_csv(r"Results/OPE_n_observations_result.csv")
SetPlotRC()
# Plotting results
sns.set(style="whitegrid")
plt.figure(figsize=(8, 5))
sns.lineplot(
    data=full_results, x="Observation Size", y="MSE", hue="Estimator"
    # , marker="o"
)
plt.yscale("log")
plt.title("Number of Observations vs MSE")
plt.tight_layout()
ApplyFont(plt.gca(), xlabel_text_size = 15.0, ylabel_text_size = 15.0, title_text_size = 15.0, ticks_text_size = 15,)
plt.show()

# %%
full_results.loc[(full_results['Estimator'] == 'dr_bis') & (full_results['Observation Size'] == 5000), 'MSE'].mean()
# Out:
# np.float64(0.005292602709488294)

# %%
full_results.loc[(full_results['Estimator'] == 'dr_bis') & (full_results['Observation Size'] == 5000), 'MSE']
# Out:
# 54    0.001764
# 59    0.010146
# 64    0.014274
# 69    0.000071
# 74    0.000208
# Name: MSE, dtype: float64
